# %% [markdown]
# # 01. Глобальный датасет и четыре класса
#
# ## Порядок работы
#
# 1. Настраивается рабочий каталог проекта и `PYTHONPATH` к `src/`.
# 2. Вызывается `data_builder.build_global_dataset(n_per_class=...)` — генерируется сбалансированный по классам датафрейм.
# 3. Результат сохраняется в `data/global_coastal_points.parquet` (перезапись файла при повторном запуске).
#
# **Следующий шаг:** ноутбук `02_preprocess_and_split` — разбиение и масштабирование признаков.

# %%
from pathlib import Path
import sys
import os

for _p in (Path.cwd(), Path.cwd().parent):
    if (_p / "src" / "helpers.py").is_file():
        sys.path.insert(0, str((_p / "src").resolve()))
        os.chdir(_p)
        break

# %%
from helpers import init_notebook_path, ensure_dirs, PROJECT_ROOT, PLOT_DIR, DATA_DIR, RANDOM_STATE, GLOBAL_DATASET_PATH
ROOT = init_notebook_path()
ensure_dirs()
print("PROJECT_ROOT", PROJECT_ROOT)

# %% [markdown]
# ## Параметр `N_PER_CLASS`
#
# Число точек **на каждый** из четырёх классов. Итоговый размер датасета ≈ `4 × N_PER_CLASS`. Увеличение значения улучшает статистику обучения, но удлиняет генерацию и все последующие шаги.

# %%
import data_builder

N_PER_CLASS = 2000
df = data_builder.build_global_dataset(n_per_class=N_PER_CLASS)
df.to_parquet(GLOBAL_DATASET_PATH, index=False)
print(df['target_class'].value_counts())
print(df.head())
